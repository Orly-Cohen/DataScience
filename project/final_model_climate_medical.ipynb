# %% [markdown]
# #### A model that includes climate data with data on number of infections in previous weeks.

# %%
import pyodbc
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sweetviz as sv

# %%
pd.set_option('display.max_columns', None)

# %%
#import table from SQL
#-------------------------

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-MLT0SLQ\SQLEXPRESS;'
                      'Database=Dengue;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()
df = pd.read_sql_query('SELECT * FROM final_ff_t12_X order by city_name, weekofyear',conn)
df.head()
# Out:
#          city_name  weekofyear  week  altitude  city_dens  max_temp_t-2  \
# 0  Coronel_Pacheco      201242    42    411.14       23.5           NaN
# 1  Coronel_Pacheco      201243    43    411.14       23.5           NaN
# 2  Coronel_Pacheco      201244    44    411.14       23.5     30.500000
# 3  Coronel_Pacheco      201245    45    411.14       23.5     33.800000
# 4  Coronel_Pacheco      201246    46    411.14       23.5     30.942857
#
#    min_temp_t-2    DTR_t-2  BR_maxT_t-2  BR_minT_t-2  BR_t-2  rain_log_t-2  \
# 0           NaN        NaN          NaN          NaN     NaN           NaN
# 1           NaN        NaN          NaN          NaN     NaN           NaN
# 2     17.385000  13.115000          3.0          2.0     5.0      1.363236
# 3     18.942857  14.857143          3.0          2.0     5.0      0.414973
# 4     19.542857  11.400000          3.0          2.0     5.0      1.318063
#
#    dew_point_t-2  sea_level_pressure_t-2  avg_humidity_t-2  min_humidity_t-2  \
# 0            NaN                     NaN               NaN               NaN
# 1            NaN                     NaN               NaN               NaN
# 2      16.820833             1012.522052         73.302083         40.250000
# 3      17.675595             1010.251046         67.529762         32.857143
# 4      18.796429             1008.971495         75.940476         49.285714
#
#    Gust_t-2  avg_wind_t-2  max_temp_t-4  min_temp_t-4  DTR_t-4  BR_maxT_t-4  \
# 0       NaN           NaN           NaN           NaN      NaN          NaN
# 1       NaN           NaN           NaN           NaN      NaN          NaN
# 2  9.975000      1.661458           NaN           NaN      NaN          NaN
# 3  8.271429      1.630357           NaN           NaN      NaN          NaN
# 4  9.828571      1.503571          30.5        17.385   13.115          3.0
#
#    BR_minT_t-4  BR_t-4  rain_log_t-4  dew_point_t-4  sea_level_pressure_t-4  \
# 0          NaN     NaN           NaN            NaN                     NaN
# 1          NaN     NaN           NaN            NaN                     NaN
# 2          NaN     NaN           NaN            NaN                     NaN
# 3          NaN     NaN           NaN            NaN                     NaN
# 4          2.0     5.0      1.363236      16.820833             1012.522052
#
#    avg_humidity_t-4  min_humidity_t-4  Gust_t-4  avg_wind_t-4  max_temp_t-6  \
# 0               NaN               NaN       NaN           NaN           NaN
# 1               NaN               NaN       NaN           NaN           NaN
# 2               NaN               NaN       NaN           NaN           NaN
# 3               NaN               NaN       NaN           NaN           NaN
# 4         73.302083             40.25     9.975      1.661458           NaN
#
#    min_temp_t-6  DTR_t-6  BR_maxT_t-6  BR_minT_t-6  BR_t-6  rain_log_t-6  \
# 0           NaN      NaN          NaN          NaN     NaN           NaN
# 1           NaN      NaN          NaN          NaN     NaN           NaN
# 2           NaN      NaN          NaN          NaN     NaN           NaN
# 3           NaN      NaN          NaN          NaN     NaN           NaN
# 4           NaN      NaN          NaN          NaN     NaN           NaN
#
#    dew_point_t-6  sea_level_pressure_t-6  avg_humidity_t-6  min_humidity_t-6  \
# 0            NaN                     NaN               NaN               NaN
# 1            NaN                     NaN               NaN               NaN
# 2            NaN                     NaN               NaN               NaN
# 3            NaN                     NaN               NaN               NaN
# 4            NaN                     NaN               NaN               NaN
#
#    Gust_t-6  avg_wind_t-6  max_temp_t-8  min_temp_t-8  DTR_t-8  BR_maxT_t-8  \
# 0       NaN           NaN           NaN           NaN      NaN          NaN
# 1       NaN           NaN           NaN           NaN      NaN          NaN
# 2       NaN           NaN           NaN           NaN      NaN          NaN
# 3       NaN           NaN           NaN           NaN      NaN          NaN
# 4       NaN           NaN           NaN           NaN      NaN          NaN
#
#    BR_minT_t-8  BR_t-8  rain_log_t-8  dew_point_t-8  sea_level_pressure_t-8  \
# 0          NaN     NaN           NaN            NaN                     NaN
# 1          NaN     NaN           NaN            NaN                     NaN
# 2          NaN     NaN           NaN            NaN                     NaN
# 3          NaN     NaN           NaN            NaN                     NaN
# 4          NaN     NaN           NaN            NaN                     NaN
#
#    avg_humidity_t-8  min_humidity_t-8  Gust_t-8  avg_wind_t-8  max_temp_t-10  \
# 0               NaN               NaN       NaN           NaN            NaN
# 1               NaN               NaN       NaN           NaN            NaN
# 2               NaN               NaN       NaN           NaN            NaN
# 3               NaN               NaN       NaN           NaN            NaN
# 4               NaN               NaN       NaN           NaN            NaN
#
#    min_temp_t-10  DTR_t-10  BR_maxT_t-10  BR_minT_t-10  BR_t-10  \
# 0            NaN       NaN           NaN           NaN      NaN
# 1            NaN       NaN           NaN           NaN      NaN
# 2            NaN       NaN           NaN           NaN      NaN
# 3            NaN       NaN           NaN           NaN      NaN
# 4            NaN       NaN           NaN           NaN      NaN
#
#    rain_log_t-10  dew_point_t-10  sea_level_pressure_t-10  avg_humidity_t-10  \
# 0            NaN             NaN                      NaN                NaN
# 1            NaN             NaN                      NaN                NaN
# 2            NaN             NaN                      NaN                NaN
# 3            NaN             NaN                      NaN                NaN
# 4            NaN             NaN                      NaN                NaN
#
#    min_humidity_t-10  Gust_t-10  avg_wind_t-10  max_temp_t-12  min_temp_t-12  \
# 0                NaN        NaN            NaN            NaN            NaN
# 1                NaN        NaN            NaN            NaN            NaN
# 2                NaN        NaN            NaN            NaN            NaN
# 3                NaN        NaN            NaN            NaN            NaN
# 4                NaN        NaN            NaN            NaN            NaN
#
#    DTR_t-12  BR_maxT_t-12  BR_minT_t-12  BR_t-12  rain_log_t-12  \
# 0       NaN           NaN           NaN      NaN            NaN
# 1       NaN           NaN           NaN      NaN            NaN
# 2       NaN           NaN           NaN      NaN            NaN
# 3       NaN           NaN           NaN      NaN            NaN
# 4       NaN           NaN           NaN      NaN            NaN
#
#    dew_point_t-12  sea_level_pressure_t-12  avg_humidity_t-12  \
# 0             NaN                      NaN                NaN
# 1             NaN                      NaN                NaN
# 2             NaN                      NaN                NaN
# 3             NaN                      NaN                NaN
# 4             NaN                      NaN                NaN
#
#    min_humidity_t-12  Gust_t-12  avg_wind_t-12  Dengue_cases_t-12  \
# 0                NaN        NaN            NaN                NaN
# 1                NaN        NaN            NaN                NaN
# 2                NaN        NaN            NaN                NaN
# 3                NaN        NaN            NaN                NaN
# 4                NaN        NaN            NaN                NaN
#
#    non_Dengue_cases_t-12  Dengue_cases
# 0                    NaN             0
# 1                    NaN             0
# 2                    NaN             0
# 3                    NaN             0
# 4                    NaN             0

# %%
# Lag operation created NaN values
# drop rows with NaNs
df.dropna(how = 'any', inplace = True)

# %%
df.isnull().sum()
# Out:
# city_name                0
# weekofyear               0
# week                     0
# altitude                 0
# city_dens                0
#                         ..
# Gust_t-12                0
# avg_wind_t-12            0
# Dengue_cases_t-12        0
# non_Dengue_cases_t-12    0
# Dengue_cases             0
# Length: 86, dtype: int64

# %%
df.shape
# Out:
# (1970, 86)

# %%
df.head()
# Out:
#           city_name  weekofyear  week  altitude  city_dens  max_temp_t-2  \
# 12  Coronel_Pacheco      201302     2    411.14       23.5     33.242857
# 13  Coronel_Pacheco      201303     3    411.14       23.5     31.828571
# 14  Coronel_Pacheco      201304     4    411.14       23.5     28.700000
# 15  Coronel_Pacheco      201305     5    411.14       23.5     29.914286
# 16  Coronel_Pacheco      201306     6    411.14       23.5     28.842857
#
#     min_temp_t-2    DTR_t-2  BR_maxT_t-2  BR_minT_t-2  BR_t-2  rain_log_t-2  \
# 12     19.557143  13.685714          3.0          2.0     5.0      1.033424
# 13     19.771429  12.057143          3.0          2.0     5.0      1.209515
# 14     20.257143   8.442857          3.0          2.0     5.0      1.828660
# 15     19.914286  10.000000          3.0          2.0     5.0      1.846337
# 16     19.571429   9.271429          3.0          2.0     5.0      1.193125
#
#     dew_point_t-2  sea_level_pressure_t-2  avg_humidity_t-2  min_humidity_t-2  \
# 12      19.814286             1010.120019         74.041667         40.000000
# 13      19.352381             1012.447704         73.494048         41.428571
# 14      19.841667             1010.336466         82.452381         57.285714
# 15      20.057143             1008.920131         84.500000         55.000000
# 16      19.674405             1011.259805         82.136905         57.000000
#
#     Gust_t-2  avg_wind_t-2  max_temp_t-4  min_temp_t-4    DTR_t-4  \
# 12  8.785714      1.600595     31.600000     20.985714  10.614286
# 13  7.028571      1.579167     32.428571     20.428571  12.000000
# 14  8.757143      1.429167     33.242857     19.557143  13.685714
# 15  9.985714      1.408333     31.828571     19.771429  12.057143
# 16  8.328571      1.410714     28.700000     20.257143   8.442857
#
#     BR_maxT_t-4  BR_minT_t-4  BR_t-4  rain_log_t-4  dew_point_t-4  \
# 12          3.0          2.0     5.0      1.946452      21.239286
# 13          3.0          2.0     5.0      1.113943      20.659524
# 14          3.0          2.0     5.0      1.033424      19.814286
# 15          3.0          2.0     5.0      1.209515      19.352381
# 16          3.0          2.0     5.0      1.828660      19.841667
#
#     sea_level_pressure_t-4  avg_humidity_t-4  min_humidity_t-4   Gust_t-4  \
#     sea_level_pressure_t-10  avg_humidity_t-10  min_humidity_t-10  Gust_t-10  \
# 12              1008.971495          75.940476          49.285714   9.828571
# 13              1010.552646          81.071429          59.142857   8.442857
# 14              1011.311306          82.226190          57.285714   7.157143
# 15              1010.562545          78.940476          52.428571   7.285714
# 16              1010.565401          81.547619          54.428571   8.671429
#
#     avg_wind_t-10  max_temp_t-12  min_temp_t-12   DTR_t-12  BR_maxT_t-12  \
# 12       1.503571      30.500000      17.385000  13.115000           3.0
# 13       1.662500      33.800000      18.942857  14.857143           3.0
# 14       1.369048      30.942857      19.542857  11.400000           3.0
# 15       1.297619      27.257143      19.400000   7.857143           3.0
# 16       1.590476      26.542857      17.485714   9.057143           3.0
#
#     BR_minT_t-12  BR_t-12  rain_log_t-12  dew_point_t-12  \
# 12           2.0      5.0       1.363236       16.820833
# 13           2.0      5.0       0.414973       17.675595
# 14           2.0      5.0       1.318063       18.796429
# 15           2.0      5.0       2.063709       18.836310
# 16           2.0      5.0       2.043755       17.506548
#
#     sea_level_pressure_t-12  avg_humidity_t-12  min_humidity_t-12  Gust_t-12  \
# 12              1012.522052          73.302083          40.250000   9.975000
# 13              1010.251046          67.529762          32.857143   8.271429
# 14              1008.971495          75.940476          49.285714   9.828571
# 15              1010.552646          81.071429          59.142857   8.442857
# 16              1011.311306          82.226190          57.285714   7.157143
#
#     avg_wind_t-12  Dengue_cases_t-12  non_Dengue_cases_t-12  Dengue_cases
# 12       1.661458                0.0                    0.0             0
# 13       1.630357                0.0                    0.0             0
# 14       1.503571                0.0                    0.0             0
# 15       1.662500                0.0                    0.0             0
# 16       1.369048                0.0                    0.0             0

# %% [markdown]
# Drop variables with high correlations (between lagged variables)
# <br> see details in the 'final_model_only_climate' notebook

# %%
# keep only min_temp_t-2 and in_temp_t-12
df.drop(columns = ['min_temp_t-4', 'min_temp_t-6', 'min_temp_t-8', 'min_temp_t-10'] , inplace = True)

# %%
#Keep only dew_point_t-8

df.drop(columns = ['dew_point_t-2', 'dew_point_t-4', 'dew_point_t-6', 'dew_point_t-10', 'dew_point_t-12'] , inplace = True)

# %%
# Keep only avg_wind_t-6

df.drop(columns = ['avg_wind_t-2', 'avg_wind_t-4', 'avg_wind_t-8', 'avg_wind_t-10', 'avg_wind_t-12'] , inplace = True)

# %%
# keep only sea_level_pressure_t-2 , sea_level_pressure_t-8, sea_level_pressure_t-12

df.drop(columns = ['sea_level_pressure_t-4', 'sea_level_pressure_t-6', 'sea_level_pressure_t-10'] , inplace = True)

# %%
df.shape
# Out:
# (1970, 69)

# %%
df.head()
# Out:
#           city_name  weekofyear  week  altitude  city_dens  max_temp_t-2  \
# 12  Coronel_Pacheco      201302     2    411.14       23.5     33.242857
# 13  Coronel_Pacheco      201303     3    411.14       23.5     31.828571
# 14  Coronel_Pacheco      201304     4    411.14       23.5     28.700000
# 15  Coronel_Pacheco      201305     5    411.14       23.5     29.914286
# 16  Coronel_Pacheco      201306     6    411.14       23.5     28.842857
#
#     max_temp_t-10   DTR_t-10  BR_maxT_t-10  BR_minT_t-10  BR_t-10  \
# 12      30.942857  11.400000           3.0           2.0      5.0
# 13      27.257143   7.857143           3.0           2.0      5.0
# 14      26.542857   9.057143           3.0           2.0      5.0
# 15      28.585714  10.271429           3.0           2.0      5.0
# 16      28.642857   9.371429           3.0           2.0      5.0
#
#     rain_log_t-10  avg_humidity_t-10  min_humidity_t-10  Gust_t-10  \
# 12       1.318063          75.940476          49.285714   9.828571
# 13       2.063709          81.071429          59.142857   8.442857
# 14       2.043755          82.226190          57.285714   7.157143
# 15       1.570543          78.940476          52.428571   7.285714
# 16       1.846337          81.547619          54.428571   8.671429
#
#     max_temp_t-12  min_temp_t-12   DTR_t-12  BR_maxT_t-12  BR_minT_t-12  \
# 12      30.500000      17.385000  13.115000           3.0           2.0
# 13      33.800000      18.942857  14.857143           3.0           2.0
# 14      30.942857      19.542857  11.400000           3.0           2.0
# 15      27.257143      19.400000   7.857143           3.0           2.0
# 16      26.542857      17.485714   9.057143           3.0           2.0
#
#     BR_t-12  rain_log_t-12  sea_level_pressure_t-12  avg_humidity_t-12  \
# 12      5.0       1.363236              1012.522052          73.302083
# 13      5.0       0.414973              1010.251046          67.529762
# 14      5.0       1.318063              1008.971495          75.940476
# 15      5.0       2.063709              1010.552646          81.071429
# 16      5.0       2.043755              1011.311306          82.226190
#
#     min_humidity_t-12  Gust_t-12  Dengue_cases_t-12  non_Dengue_cases_t-12  \
# 12          40.250000   9.975000                0.0                    0.0
# 13          32.857143   8.271429                0.0                    0.0
# 14          49.285714   9.828571                0.0                    0.0
# 15          59.142857   8.442857                0.0                    0.0
# 16          57.285714   7.157143                0.0                    0.0
#
#     Dengue_cases
# 12             0
# 13             0
# 14             0
# 15             0
# 16             0

# %% [markdown]
# --------
# ## Feature Selection

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import LinearSVR

# %%
# arrange dataframe: leave only relevant columns for feature selection
# city name is represented by city_des and altitude
# weekofyear includes information on the year,this information cannot be used for future predictions therefore is excluded


df.drop(columns=['city_name', 'weekofyear'], inplace = True)

df.head()
# Out:
#     week  altitude  city_dens  max_temp_t-2  min_temp_t-2    DTR_t-2  \
# 12     2    411.14       23.5     33.242857     19.557143  13.685714
# 13     3    411.14       23.5     31.828571     19.771429  12.057143
# 14     4    411.14       23.5     28.700000     20.257143   8.442857
# 15     5    411.14       23.5     29.914286     19.914286  10.000000
# 16     6    411.14       23.5     28.842857     19.571429   9.271429
#
#     BR_maxT_t-2  BR_minT_t-2  BR_t-2  rain_log_t-2  sea_level_pressure_t-2  \
# 12          3.0          2.0     5.0      1.033424             1010.120019
# 13          3.0          2.0     5.0      1.209515             1012.447704
# 14          3.0          2.0     5.0      1.828660             1010.336466
# 15          3.0          2.0     5.0      1.846337             1008.920131
# 16          3.0          2.0     5.0      1.193125             1011.259805
#
#     avg_humidity_t-2  min_humidity_t-2  Gust_t-2  max_temp_t-4    DTR_t-4  \
# 12         74.041667         40.000000  8.785714     31.600000  10.614286
# 13         73.494048         41.428571  7.028571     32.428571  12.000000
# 14         82.452381         57.285714  8.757143     33.242857  13.685714
# 15         84.500000         55.000000  9.985714     31.828571  12.057143
# 16         82.136905         57.000000  8.328571     28.700000   8.442857
#
#     BR_maxT_t-4  BR_minT_t-4  BR_t-4  rain_log_t-4  avg_humidity_t-4  \
# 12          3.0          2.0     5.0      1.946452         83.720238
# 13          3.0          2.0     5.0      1.113943         77.773810
# 14          3.0          2.0     5.0      1.033424         74.041667
# 15          3.0          2.0     5.0      1.209515         73.494048
# 16          3.0          2.0     5.0      1.828660         82.452381
#
#     min_humidity_t-4   Gust_t-4  max_temp_t-6    DTR_t-6  BR_maxT_t-6  \
# 12         53.571429  11.285714     28.642857   9.371429          3.0
# 13         45.714286   8.857143     32.157143  11.871429          3.0
# 14         40.000000   8.785714     31.600000  10.614286          3.0
# 15         41.428571   7.028571     32.428571  12.000000          3.0
# 16         57.285714   8.757143     33.242857  13.685714          3.0
#
#     BR_minT_t-6  BR_t-6  rain_log_t-6  avg_humidity_t-6  min_humidity_t-6  \
# 12          2.0     5.0      1.846337         81.547619         54.428571
# 13          2.0     5.0      1.428135         76.744048         45.142857
# 14          2.0     5.0      1.946452         83.720238         53.571429
# 15          2.0     5.0      1.113943         77.773810         45.714286
# 16          2.0     5.0      1.033424         74.041667         40.000000
#
#      Gust_t-6  avg_wind_t-6  max_temp_t-8    DTR_t-8  BR_maxT_t-8  \
# 12   8.671429      1.590476     26.542857   9.057143          3.0
# 13   8.785714      1.567262     28.585714  10.271429          3.0
# 14  11.285714      1.392857     28.642857   9.371429          3.0
# 15   8.857143      1.450595     32.157143  11.871429          3.0
# 16   8.785714      1.600595     31.600000  10.614286          3.0
#
#     BR_minT_t-8  BR_t-8  rain_log_t-8  dew_point_t-8  sea_level_pressure_t-8  \
# 12          2.0     5.0      2.043755      17.506548             1011.311306
# 13          2.0     5.0      1.570543      18.238095             1010.562545
# 14          2.0     5.0      1.846337      19.186309             1010.565401
# 15          2.0     5.0      1.428135      20.267262             1009.869249
# 16          2.0     5.0      1.946452      21.239286             1007.250784
#
#     avg_humidity_t-8  min_humidity_t-8   Gust_t-8  max_temp_t-10   DTR_t-10  \
# 12         82.226190         57.285714   7.157143      30.942857  11.400000
# 13         78.940476         52.428571   7.285714      27.257143   7.857143
# 14         81.547619         54.428571   8.671429      26.542857   9.057143
# 15         76.744048         45.142857   8.785714      28.585714  10.271429
# 16         83.720238         53.571429  11.285714      28.642857   9.371429
#
#     BR_maxT_t-10  BR_minT_t-10  BR_t-10  rain_log_t-10  avg_humidity_t-10  \
# 12           3.0           2.0      5.0       1.318063          75.940476
# 13           3.0           2.0      5.0       2.063709          81.071429
# 14           3.0           2.0      5.0       2.043755          82.226190
# 15           3.0           2.0      5.0       1.570543          78.940476
# 16           3.0           2.0      5.0       1.846337          81.547619
#
#     min_humidity_t-10  Gust_t-10  max_temp_t-12  min_temp_t-12   DTR_t-12  \
# 12          49.285714   9.828571      30.500000      17.385000  13.115000
# 13          59.142857   8.442857      33.800000      18.942857  14.857143
# 14          57.285714   7.157143      30.942857      19.542857  11.400000
# 15          52.428571   7.285714      27.257143      19.400000   7.857143
# 16          54.428571   8.671429      26.542857      17.485714   9.057143
#
#     BR_maxT_t-12  BR_minT_t-12  BR_t-12  rain_log_t-12  \
# 12           3.0           2.0      5.0       1.363236
# 13           3.0           2.0      5.0       0.414973
# 14           3.0           2.0      5.0       1.318063
# 15           3.0           2.0      5.0       2.063709
# 16           3.0           2.0      5.0       2.043755
#
#     sea_level_pressure_t-12  avg_humidity_t-12  min_humidity_t-12  Gust_t-12  \
# 12              1012.522052          73.302083          40.250000   9.975000
# 13              1010.251046          67.529762          32.857143   8.271429
# 14              1008.971495          75.940476          49.285714   9.828571
# 15              1010.552646          81.071429          59.142857   8.442857
# 16              1011.311306          82.226190          57.285714   7.157143
#
#     Dengue_cases_t-12  non_Dengue_cases_t-12  Dengue_cases
# 12                0.0                    0.0             0
# 13                0.0                    0.0             0
# 14                0.0                    0.0             0
# 15                0.0                    0.0             0
# 16                0.0                    0.0             0

# %%
X = df.iloc[:,:-1]
X.head()
# Out:
#     week  altitude  city_dens  max_temp_t-2  min_temp_t-2    DTR_t-2  \
# 12     2    411.14       23.5     33.242857     19.557143  13.685714
# 13     3    411.14       23.5     31.828571     19.771429  12.057143
# 14     4    411.14       23.5     28.700000     20.257143   8.442857
# 15     5    411.14       23.5     29.914286     19.914286  10.000000
# 16     6    411.14       23.5     28.842857     19.571429   9.271429
#
#     BR_maxT_t-2  BR_minT_t-2  BR_t-2  rain_log_t-2  sea_level_pressure_t-2  \
# 12          3.0          2.0     5.0      1.033424             1010.120019
# 13          3.0          2.0     5.0      1.209515             1012.447704
# 14          3.0          2.0     5.0      1.828660             1010.336466
# 15          3.0          2.0     5.0      1.846337             1008.920131
# 16          3.0          2.0     5.0      1.193125             1011.259805
#
#     avg_humidity_t-2  min_humidity_t-2  Gust_t-2  max_temp_t-4    DTR_t-4  \
# 12         74.041667         40.000000  8.785714     31.600000  10.614286
# 13         73.494048         41.428571  7.028571     32.428571  12.000000
# 14         82.452381         57.285714  8.757143     33.242857  13.685714
# 15         84.500000         55.000000  9.985714     31.828571  12.057143
# 16         82.136905         57.000000  8.328571     28.700000   8.442857
#
#     BR_maxT_t-4  BR_minT_t-4  BR_t-4  rain_log_t-4  avg_humidity_t-4  \
# 12          3.0          2.0     5.0      1.946452         83.720238
# 13          3.0          2.0     5.0      1.113943         77.773810
# 14          3.0          2.0     5.0      1.033424         74.041667
# 15          3.0          2.0     5.0      1.209515         73.494048
# 16          3.0          2.0     5.0      1.828660         82.452381
#
#     min_humidity_t-4   Gust_t-4  max_temp_t-6    DTR_t-6  BR_maxT_t-6  \
# 12         53.571429  11.285714     28.642857   9.371429          3.0
# 13         45.714286   8.857143     32.157143  11.871429          3.0
# 14         40.000000   8.785714     31.600000  10.614286          3.0
# 15         41.428571   7.028571     32.428571  12.000000          3.0
# 16         57.285714   8.757143     33.242857  13.685714          3.0
#
#     BR_minT_t-6  BR_t-6  rain_log_t-6  avg_humidity_t-6  min_humidity_t-6  \
# 12          2.0     5.0      1.846337         81.547619         54.428571
# 13          2.0     5.0      1.428135         76.744048         45.142857
# 14          2.0     5.0      1.946452         83.720238         53.571429
# 15          2.0     5.0      1.113943         77.773810         45.714286
# 16          2.0     5.0      1.033424         74.041667         40.000000
#
#      Gust_t-6  avg_wind_t-6  max_temp_t-8    DTR_t-8  BR_maxT_t-8  \
# 12   8.671429      1.590476     26.542857   9.057143          3.0
# 13   8.785714      1.567262     28.585714  10.271429          3.0
# 14  11.285714      1.392857     28.642857   9.371429          3.0
# 15   8.857143      1.450595     32.157143  11.871429          3.0
# 16   8.785714      1.600595     31.600000  10.614286          3.0
#
#     BR_minT_t-8  BR_t-8  rain_log_t-8  dew_point_t-8  sea_level_pressure_t-8  \
# 12          2.0     5.0      2.043755      17.506548             1011.311306
# 13          2.0     5.0      1.570543      18.238095             1010.562545
# 14          2.0     5.0      1.846337      19.186309             1010.565401
# 15          2.0     5.0      1.428135      20.267262             1009.869249
# 16          2.0     5.0      1.946452      21.239286             1007.250784
#
#     avg_humidity_t-8  min_humidity_t-8   Gust_t-8  max_temp_t-10   DTR_t-10  \
# 12         82.226190         57.285714   7.157143      30.942857  11.400000
# 13         78.940476         52.428571   7.285714      27.257143   7.857143
# 14         81.547619         54.428571   8.671429      26.542857   9.057143
# 15         76.744048         45.142857   8.785714      28.585714  10.271429
# 16         83.720238         53.571429  11.285714      28.642857   9.371429
#
#     BR_maxT_t-10  BR_minT_t-10  BR_t-10  rain_log_t-10  avg_humidity_t-10  \
# 12           3.0           2.0      5.0       1.318063          75.940476
# 13           3.0           2.0      5.0       2.063709          81.071429
# 14           3.0           2.0      5.0       2.043755          82.226190
# 15           3.0           2.0      5.0       1.570543          78.940476
# 16           3.0           2.0      5.0       1.846337          81.547619
#
#     min_humidity_t-10  Gust_t-10  max_temp_t-12  min_temp_t-12   DTR_t-12  \
# 12          49.285714   9.828571      30.500000      17.385000  13.115000
# 13          59.142857   8.442857      33.800000      18.942857  14.857143
# 14          57.285714   7.157143      30.942857      19.542857  11.400000
# 15          52.428571   7.285714      27.257143      19.400000   7.857143
# 16          54.428571   8.671429      26.542857      17.485714   9.057143
#
#     BR_maxT_t-12  BR_minT_t-12  BR_t-12  rain_log_t-12  \
# 12           3.0           2.0      5.0       1.363236
# 13           3.0           2.0      5.0       0.414973
# 14           3.0           2.0      5.0       1.318063
# 15           3.0           2.0      5.0       2.063709
# 16           3.0           2.0      5.0       2.043755
#
#     sea_level_pressure_t-12  avg_humidity_t-12  min_humidity_t-12  Gust_t-12  \
# 12              1012.522052          73.302083          40.250000   9.975000
# 13              1010.251046          67.529762          32.857143   8.271429
# 14              1008.971495          75.940476          49.285714   9.828571
# 15              1010.552646          81.071429          59.142857   8.442857
# 16              1011.311306          82.226190          57.285714   7.157143
#
#     Dengue_cases_t-12  non_Dengue_cases_t-12
# 12                0.0                    0.0
# 13                0.0                    0.0
# 14                0.0                    0.0
# 15                0.0                    0.0
# 16                0.0                    0.0

# %%
y = df.iloc[:,-1:]
y
# Out:
#       Dengue_cases
# 12               0
# 13               0
# 14               0
# 15               0
# 16               0
# ...            ...
# 2025             0
# 2026             0
# 2027             0
# 2028             0
# 2029             0
#
# [1970 rows x 1 columns]

# %%
# Normalize data

scaler = MinMaxScaler()
X_scale = scaler.fit_transform(X)
scale_df = pd.DataFrame( data = X_scale, columns= list(X.columns), index= df.index)
scale_df.head()
# Out:
#         week  altitude  city_dens  max_temp_t-2  min_temp_t-2   DTR_t-2  \
# 12  0.019231  0.196227        0.0      0.730511      0.707677  0.622417
# 13  0.038462  0.196227        0.0      0.663978      0.719115  0.531797
# 14  0.057692  0.196227        0.0      0.516801      0.745043  0.330684
# 15  0.076923  0.196227        0.0      0.573925      0.726741  0.417329
# 16  0.096154  0.196227        0.0      0.523522      0.708439  0.376789
#
#     BR_maxT_t-2  BR_minT_t-2  BR_t-2  rain_log_t-2  sea_level_pressure_t-2  \
# 12          1.0     0.666667    0.75      0.661132                0.250657
# 13          1.0     0.666667    0.75      0.703740                0.352141
# 14          1.0     0.666667    0.75      0.853548                0.260094
# 15          1.0     0.666667    0.75      0.857826                0.198343
# 16          1.0     0.666667    0.75      0.699774                0.300350
#
#     avg_humidity_t-2  min_humidity_t-2  Gust_t-2  max_temp_t-4   DTR_t-4  \
# 12          0.569501          0.272727  0.396570      0.653226  0.451510
# 13          0.557528          0.294372  0.264737      0.692204  0.528617
# 14          0.753387          0.534632  0.394427      0.730511  0.622417
# 15          0.798155          0.500000  0.486602      0.663978  0.531797
# 16          0.746490          0.530303  0.362272      0.516801  0.330684
#
#     BR_maxT_t-4  BR_minT_t-4  BR_t-4  rain_log_t-4  avg_humidity_t-4  \
# 12          1.0     0.666667    0.75      0.882050          0.781107
# 13          1.0     0.666667    0.75      0.680615          0.651098
# 14          1.0     0.666667    0.75      0.661132          0.569501
# 15          1.0     0.666667    0.75      0.703740          0.557528
# 16          1.0     0.666667    0.75      0.853548          0.753387
#
#     min_humidity_t-4  Gust_t-4  max_temp_t-6   DTR_t-6  BR_maxT_t-6  \
# 12          0.478355  0.584137      0.514113  0.382353          1.0
# 13          0.359307  0.401929      0.679435  0.521463          1.0
# 14          0.272727  0.396570      0.653226  0.451510          1.0
# 15          0.294372  0.264737      0.692204  0.528617          1.0
# 16          0.534632  0.394427      0.730511  0.622417          1.0
#
#     BR_minT_t-6  BR_t-6  rain_log_t-6  avg_humidity_t-6  min_humidity_t-6  \
# 12     0.666667    0.75      0.857826          0.733606          0.491342
# 13     0.666667    0.75      0.756637          0.628584          0.350649
# 14     0.666667    0.75      0.882050          0.781107          0.478355
# 15     0.666667    0.75      0.680615          0.651098          0.359307
# 16     0.666667    0.75      0.661132          0.569501          0.272727
#
#     Gust_t-6  avg_wind_t-6  max_temp_t-8   DTR_t-8  BR_maxT_t-8  BR_minT_t-8  \
# 12  0.387996      0.319383      0.415323  0.364865          1.0     0.666667
# 13  0.396570      0.313812      0.511425  0.432432          1.0     0.666667
# 14  0.584137      0.271961      0.514113  0.382353          1.0     0.666667
# 15  0.401929      0.285816      0.679435  0.521463          1.0     0.666667
# 16  0.396570      0.321811      0.653226  0.451510          1.0     0.666667
#
#     BR_t-8  rain_log_t-8  dew_point_t-8  sea_level_pressure_t-8  \
# 12    0.75      0.905593       0.622212                0.302595
# 13    0.75      0.791094       0.673025                0.269950
# 14    0.75      0.857826       0.738889                0.270075
# 15    0.75      0.756637       0.813973                0.239723
# 16    0.75      0.882050       0.881490                0.125561
#
#     avg_humidity_t-8  min_humidity_t-8  Gust_t-8  max_temp_t-10  DTR_t-10  \
# 12          0.748442          0.534632  0.274384       0.622312  0.495231
# 13          0.676605          0.461039  0.284030       0.448925  0.298092
# 14          0.733606          0.491342  0.387996       0.415323  0.364865
# 15          0.628584          0.350649  0.396570       0.511425  0.432432
# 16          0.781107          0.478355  0.584137       0.514113  0.382353
#
#     BR_maxT_t-10  BR_minT_t-10  BR_t-10  rain_log_t-10  avg_humidity_t-10  \
# 12           1.0      0.666667     0.75       0.730004           0.611015
# 13           1.0      0.666667     0.75       0.910421           0.723195
# 14           1.0      0.666667     0.75       0.905593           0.748442
# 15           1.0      0.666667     0.75       0.791094           0.676605
# 16           1.0      0.666667     0.75       0.857826           0.733606
#
#     min_humidity_t-10  Gust_t-10  max_temp_t-12  min_temp_t-12  DTR_t-12  \
# 12           0.413420   0.474812       0.601478       0.591726  0.590660
# 13           0.562771   0.370847       0.756720       0.674886  0.687599
# 14           0.534632   0.274384       0.622312       0.706914  0.495231
# 15           0.461039   0.284030       0.448925       0.699288  0.298092
# 16           0.491342   0.387996       0.415323       0.597102  0.364865
#
#     BR_maxT_t-12  BR_minT_t-12  BR_t-12  rain_log_t-12  \
# 12           1.0      0.666667     0.75       0.717383
# 13           1.0      0.666667     0.75       0.495234
# 14           1.0      0.666667     0.75       0.706801
# 15           1.0      0.666667     0.75       0.881483
# 16           1.0      0.666667     0.75       0.876808
#
#     sea_level_pressure_t-12  avg_humidity_t-12  min_humidity_t-12  Gust_t-12  \
# 12                 0.406557           0.530878           0.264493   0.485798
# 13                 0.315404           0.409797           0.157350   0.357985
# 14                 0.264046           0.586221           0.395445   0.474812
# 15                 0.327509           0.693848           0.538302   0.370847
# 16                 0.357960           0.718071           0.511387   0.274384
#
#     Dengue_cases_t-12  non_Dengue_cases_t-12
# 12                0.0                    0.0
# 13                0.0                    0.0
# 14                0.0                    0.0
# 15                0.0                    0.0
# 16                0.0                    0.0

# %% [markdown]
# ### Univariate feature selection

# %%
# spearman rank
from scipy import stats

# %%
varSel = pd.DataFrame({'Variable': X.columns})
varSel.head()
# Out:
#        Variable
# 0          week
# 1      altitude
# 2     city_dens
# 3  max_temp_t-2
# 4  min_temp_t-2

# %%
list_of_col = list(X.columns)

# %%
coef_list = []
p_list = []

for col in list_of_col:
    coef, p = stats.spearmanr(scale_df[col], y)
    coef_list.append(coef)
    p_list.append(p)

# %%
varSel['Spearman'] = coef_list
varSel['p_value'] = p_list
varSel.head()
# Out:
#        Variable  Spearman       p_value
# 0          week -0.211429  2.407624e-21
# 1      altitude  0.246146  1.415285e-28
# 2     city_dens  0.342902  1.826898e-55
# 3  max_temp_t-2 -0.083758  1.978417e-04
# 4  min_temp_t-2  0.122672  4.708980e-08

# %%
pd.set_option("display.max_rows", 88)

# %%
varSel['Univarable'] = 0
varSel.loc[varSel['p_value']< 0.05, 'Univarable'] = 1

varSel.sort_values("Variable")
# Out:
#                    Variable  Spearman        p_value  Univarable
# 46             BR_maxT_t-10  0.022567   3.167693e-01           0
# 56             BR_maxT_t-12  0.023084   3.058014e-01           0
# 6               BR_maxT_t-2  0.002685   9.052144e-01           0
# 16              BR_maxT_t-4  0.014251   5.272917e-01           0
# 25              BR_maxT_t-6  0.020636   3.599529e-01           0
# 35              BR_maxT_t-8  0.023895   2.891146e-01           0
# 47             BR_minT_t-10  0.186561   6.907656e-17           1
# 57             BR_minT_t-12  0.158237   1.624946e-12           1
# 7               BR_minT_t-2  0.151224   1.513389e-11           1
# 17              BR_minT_t-4  0.162735   3.679842e-13           1
# 26              BR_minT_t-6  0.180721   6.329238e-16           1
# 36              BR_minT_t-8  0.185831   9.150230e-17           1
# 48                  BR_t-10  0.142258   2.263045e-10           1
# 58                  BR_t-12  0.122449   4.982047e-08           1
# 8                    BR_t-2  0.112559   5.480988e-07           1
# 18                   BR_t-4  0.125810   2.109664e-08           1
# 27                   BR_t-6  0.139567   4.934709e-10           1
# 37                   BR_t-8  0.142997   1.821764e-10           1
# 45                 DTR_t-10 -0.241372   1.646872e-27           1
# 55                 DTR_t-12 -0.205816   2.751199e-20           1
# 5                   DTR_t-2 -0.267665   1.135957e-33           1
# 15                  DTR_t-4 -0.268727   6.185318e-34           1
# 24                  DTR_t-6 -0.274027   2.856386e-35           1
# 34                  DTR_t-8 -0.250557   1.397764e-29           1
# 64        Dengue_cases_t-12  0.603030  2.060625e-195           1
# 52                Gust_t-10  0.371335   1.894376e-65           1
# 63                Gust_t-12  0.393149   8.044612e-74           1
# 13                 Gust_t-2  0.248676   3.772528e-29           1
# 22                 Gust_t-4  0.287095   1.082752e-38           1
# 31                 Gust_t-6  0.317622   2.022249e-47           1
# 43                 Gust_t-8  0.339789   1.965556e-54           1
# 1                  altitude  0.246146   1.415285e-28           1
# 50        avg_humidity_t-10  0.012680   5.738037e-01           0
# 61        avg_humidity_t-12 -0.027877   2.161748e-01           0
# 11         avg_humidity_t-2  0.090978   5.258270e-05           1
# 20         avg_humidity_t-4  0.077751   5.523796e-04           1
# 29         avg_humidity_t-6  0.073669   1.067261e-03           1
# 41         avg_humidity_t-8  0.038779   8.529306e-02           0
# 32             avg_wind_t-6  0.225343   4.238249e-24           1
# 2                 city_dens  0.342902   1.826898e-55           1
# 39            dew_point_t-8  0.126597   1.719350e-08           1
# 44            max_temp_t-10 -0.010518   6.408224e-01           0
# 53            max_temp_t-12 -0.010897   6.288194e-01           0
# 3              max_temp_t-2 -0.083758   1.978417e-04           1
# 14             max_temp_t-4 -0.058380   9.549162e-03           1
# 23             max_temp_t-6 -0.045744   4.234537e-02           1
# 33             max_temp_t-8 -0.025072   2.660100e-01           0
# 51        min_humidity_t-10  0.145000   1.007113e-10           1
# 62        min_humidity_t-12  0.104534   3.327440e-06           1
# 12         min_humidity_t-2  0.202068   1.345562e-19           1
# 21         min_humidity_t-4  0.195658   1.892507e-18           1
# 30         min_humidity_t-6  0.198081   7.041817e-19           1
# 42         min_humidity_t-8  0.164800   1.834568e-13           1
# 54            min_temp_t-12  0.152276   1.089937e-11           1
# 4              min_temp_t-2  0.122672   4.708980e-08           1
# 65    non_Dengue_cases_t-12  0.029923   1.843201e-01           0
# 49            rain_log_t-10  0.145186   9.525449e-11           1
# 59            rain_log_t-12  0.129861   7.264922e-09           1
# 9              rain_log_t-2  0.098310   1.235145e-05           1
# 19             rain_log_t-4  0.122017   5.555134e-08           1
# 28             rain_log_t-6  0.141609   2.735011e-10           1
# 38             rain_log_t-8  0.134805   1.890857e-09           1
# 60  sea_level_pressure_t-12 -0.278947   1.546561e-36           1
# 10   sea_level_pressure_t-2 -0.222663   1.487768e-23           1
# 40   sea_level_pressure_t-8 -0.297917   1.147675e-41           1
# 0                      week -0.211429   2.407624e-21           1

# %% [markdown]
# ####  LASSO (L1 penalization)

# %%
lassomod = Lasso(alpha=0.01 ,max_iter = 1000).fit(scale_df, y)

# %%
model = SelectFromModel(lassomod, prefit=True)
varSel['Lasso'] = model.get_support().astype('int64')

# %% [markdown]
# ####  Random Forest

# %%
y= df['Dengue_cases']

# %%
rfmod = RandomForestRegressor().fit(scale_df, y)

# %%
model = SelectFromModel(rfmod, prefit=True)
varSel['RandomForest'] = model.get_support().astype('int64')

# %% [markdown]
# #### GradientBoosting

# %%
gbmod = GradientBoostingRegressor().fit(scale_df, y)

# %%
model = SelectFromModel(gbmod, prefit=True)
varSel['GradientBoost'] = model.get_support().astype('int64')

# %% [markdown]
# #### SVM

# %%
svmmod = LinearSVR(C=0.01).fit(scale_df, y)

# %%
model = SelectFromModel(svmmod, prefit=True)
varSel['SVM'] = model.get_support().astype('int64')

# %% [markdown]
# #### Linear Regression

# %%
linear = LinearRegression().fit(scale_df, y)
model = SelectFromModel(linear, prefit=True)
varSel['Linear Reg'] = model.get_support().astype('int64')

# %% [markdown]
# #### AdaBoost

# %%
ada = AdaBoostRegressor().fit(scale_df, y)
model = SelectFromModel(ada, prefit=True)
varSel['AdaBoost'] = model.get_support().astype('int64')

# %% [markdown]
# ### Summarization of models selection

# %%
varSel['Sum'] = np.sum(varSel.iloc[:, 3:10] ,axis=1)
varSel.sort_values("Sum", ascending=False)
# Out:
#                    Variable  Spearman        p_value  Univarable  Lasso  \
# 0                      week -0.211429   2.407624e-21           1      1
# 4              min_temp_t-2  0.122672   4.708980e-08           1      1
# 64        Dengue_cases_t-12  0.603030  2.060625e-195           1      1
# 31                 Gust_t-6  0.317622   2.022249e-47           1      1
# 52                Gust_t-10  0.371335   1.894376e-65           1      1
# 63                Gust_t-12  0.393149   8.044612e-74           1      1
# 40   sea_level_pressure_t-8 -0.297917   1.147675e-41           1      1
# 32             avg_wind_t-6  0.225343   4.238249e-24           1      1
# 22                 Gust_t-4  0.287095   1.082752e-38           1      1
# 20         avg_humidity_t-4  0.077751   5.523796e-04           1      1
# 55                 DTR_t-12 -0.205816   2.751199e-20           1      1
# 45                 DTR_t-10 -0.241372   1.646872e-27           1      1
# 43                 Gust_t-8  0.339789   1.965556e-54           1      1
# 42         min_humidity_t-8  0.164800   1.834568e-13           1      1
# 29         avg_humidity_t-6  0.073669   1.067261e-03           1      1
# 21         min_humidity_t-4  0.195658   1.892507e-18           1      1
# 60  sea_level_pressure_t-12 -0.278947   1.546561e-36           1      1
# 3              max_temp_t-2 -0.083758   1.978417e-04           1      1
# 13                 Gust_t-2  0.248676   3.772528e-29           1      1
# 17              BR_minT_t-4  0.162735   3.679842e-13           1      1
# 1                  altitude  0.246146   1.415285e-28           1      1
# 59            rain_log_t-12  0.129861   7.264922e-09           1      1
# 57             BR_minT_t-12  0.158237   1.624946e-12           1      1
# 2                 city_dens  0.342902   1.826898e-55           1      1
# 54            min_temp_t-12  0.152276   1.089937e-11           1      0
# 47             BR_minT_t-10  0.186561   6.907656e-17           1      1
# 5                   DTR_t-2 -0.267665   1.135957e-33           1      0
# 7               BR_minT_t-2  0.151224   1.513389e-11           1      1
# 41         avg_humidity_t-8  0.038779   8.529306e-02           0      1
# 36              BR_minT_t-8  0.185831   9.150230e-17           1      1
# 10   sea_level_pressure_t-2 -0.222663   1.487768e-23           1      1
# 34                  DTR_t-8 -0.250557   1.397764e-29           1      1
# 30         min_humidity_t-6  0.198081   7.041817e-19           1      1
# 11         avg_humidity_t-2  0.090978   5.258270e-05           1      1
# 26              BR_minT_t-6  0.180721   6.329238e-16           1      1
# 19             rain_log_t-4  0.122017   5.555134e-08           1      1
# 15                  DTR_t-4 -0.268727   6.185318e-34           1      1
# 24                  DTR_t-6 -0.274027   2.856386e-35           1      1
# 61        avg_humidity_t-12 -0.027877   2.161748e-01           0      1
# 38             rain_log_t-8  0.134805   1.890857e-09           1      1
# 50        avg_humidity_t-10  0.012680   5.738037e-01           0      1
# 58                  BR_t-12  0.122449   4.982047e-08           1      0
# 16              BR_maxT_t-4  0.014251   5.272917e-01           0      1
# 56             BR_maxT_t-12  0.023084   3.058014e-01           0      1
# 28             rain_log_t-6  0.141609   2.735011e-10           1      1
# 14             max_temp_t-4 -0.058380   9.549162e-03           1      1
# 53            max_temp_t-12 -0.010897   6.288194e-01           0      1
# 23             max_temp_t-6 -0.045744   4.234537e-02           1      1
# 51        min_humidity_t-10  0.145000   1.007113e-10           1      1
# 49            rain_log_t-10  0.145186   9.525449e-11           1      1
# 18                   BR_t-4  0.125810   2.109664e-08           1      0
# 48                  BR_t-10  0.142258   2.263045e-10           1      0
# 12         min_humidity_t-2  0.202068   1.345562e-19           1      1
# 62        min_humidity_t-12  0.104534   3.327440e-06           1      1
# 25              BR_maxT_t-6  0.020636   3.599529e-01           0      1
# 6               BR_maxT_t-2  0.002685   9.052144e-01           0      1
# 37                   BR_t-8  0.142997   1.821764e-10           1      0
# 8                    BR_t-2  0.112559   5.480988e-07           1      0
# 27                   BR_t-6  0.139567   4.934709e-10           1      0
# 9              rain_log_t-2  0.098310   1.235145e-05           1      1
# 39            dew_point_t-8  0.126597   1.719350e-08           1      1
# 33             max_temp_t-8 -0.025072   2.660100e-01           0      1
# 46             BR_maxT_t-10  0.022567   3.167693e-01           0      1
# 44            max_temp_t-10 -0.010518   6.408224e-01           0      1
# 35              BR_maxT_t-8  0.023895   2.891146e-01           0      1
# 65    non_Dengue_cases_t-12  0.029923   1.843201e-01           0      1
#
#     RandomForest  GradientBoost  SVM  Linear Reg  AdaBoost  Sum
# 0              1              1    1           0         1    6
# 4              1              1    0           1         1    6
# 64             1              1    1           0         1    6
# 31             1              1    1           0         1    6
# 52             0              1    1           0         1    5
# 63             0              1    1           0         1    5
# 40             0              1    1           0         1    5
# 32             0              1    1           0         1    5
# 22             1              0    1           0         1    5
# 20             1              1    0           0         0    4
# 55             0              0    1           1         0    4
# 45             0              1    1           0         0    4
# 43             0              0    1           0         1    4
# 42             0              1    0           0         1    4
# 29             1              1    0           0         0    4
# 21             1              0    0           0         1    4
# 60             0              0    1           0         1    4
# 3              1              0    0           1         0    4
# 13             1              0    1           0         0    4
# 17             0              0    0           1         0    3
# 1              0              0    1           0         0    3
# 59             1              0    0           0         0    3
# 57             0              0    0           1         0    3
# 2              0              0    1           0         0    3
# 54             1              0    0           1         0    3
# 47             0              0    0           1         0    3
# 5              0              0    1           1         0    3
# 7              0              0    0           1         0    3
# 41             1              1    0           0         0    3
# 36             0              0    0           1         0    3
# 10             0              0    1           0         0    3
# 34             0              0    1           0         0    3
# 30             1              0    0           0         0    3
# 11             1              0    0           0         0    3
# 26             0              0    0           1         0    3
# 19             0              0    0           0         1    3
# 15             0              0    1           0         0    3
# 24             0              0    1           0         0    3
# 61             1              0    0           0         1    3
# 38             0              0    0           0         0    2
# 50             1              0    0           0         0    2
# 58             0              0    0           1         0    2
# 16             0              0    0           1         0    2
# 56             0              0    0           1         0    2
# 28             0              0    0           0         0    2
# 14             0              0    0           0         0    2
# 53             0              0    0           1         0    2
# 23             0              0    0           0         0    2
# 51             0              0    0           0         0    2
# 49             0              0    0           0         0    2
# 18             0              0    0           1         0    2
# 48             0              0    0           1         0    2
# 12             0              0    0           0         0    2
# 62             0              0    0           0         0    2
# 25             0              0    0           1         0    2
# 6              0              0    0           1         0    2
# 37             0              0    0           1         0    2
# 8              0              0    0           1         0    2
# 27             0              0    0           1         0    2
# 9              0              0    0           0         0    2
# 39             0              0    0           0         0    2
# 33             0              0    0           0         0    1
# 46             0              0    0           0         0    1
# 44             0              0    0           0         0    1
# 35             0              0    0           0         0    1
# 65             0              0    0           0         0    1

# %%
varSel.groupby('Sum')['Variable'].count()
# Out:
# Sum
# 1     5
# 2    22
# 3    20
# 4    10
# 5     5
# 6     4
# Name: Variable, dtype: int64

# %%
# Select variable with scores of 3 and higher.

varSel[varSel['Sum']>=3].sort_values("Variable", ascending=False)
# Out:
#                    Variable  Spearman        p_value  Univarable  Lasso  \
# 0                      week -0.211429   2.407624e-21           1      1
# 40   sea_level_pressure_t-8 -0.297917   1.147675e-41           1      1
# 10   sea_level_pressure_t-2 -0.222663   1.487768e-23           1      1
# 60  sea_level_pressure_t-12 -0.278947   1.546561e-36           1      1
# 19             rain_log_t-4  0.122017   5.555134e-08           1      1
# 59            rain_log_t-12  0.129861   7.264922e-09           1      1
# 4              min_temp_t-2  0.122672   4.708980e-08           1      1
# 54            min_temp_t-12  0.152276   1.089937e-11           1      0
# 42         min_humidity_t-8  0.164800   1.834568e-13           1      1
# 30         min_humidity_t-6  0.198081   7.041817e-19           1      1
# 21         min_humidity_t-4  0.195658   1.892507e-18           1      1
# 3              max_temp_t-2 -0.083758   1.978417e-04           1      1
# 2                 city_dens  0.342902   1.826898e-55           1      1
# 32             avg_wind_t-6  0.225343   4.238249e-24           1      1
# 41         avg_humidity_t-8  0.038779   8.529306e-02           0      1
# 29         avg_humidity_t-6  0.073669   1.067261e-03           1      1
# 20         avg_humidity_t-4  0.077751   5.523796e-04           1      1
# 11         avg_humidity_t-2  0.090978   5.258270e-05           1      1
# 61        avg_humidity_t-12 -0.027877   2.161748e-01           0      1
# 1                  altitude  0.246146   1.415285e-28           1      1
# 43                 Gust_t-8  0.339789   1.965556e-54           1      1
# 31                 Gust_t-6  0.317622   2.022249e-47           1      1
# 22                 Gust_t-4  0.287095   1.082752e-38           1      1
# 13                 Gust_t-2  0.248676   3.772528e-29           1      1
# 63                Gust_t-12  0.393149   8.044612e-74           1      1
# 52                Gust_t-10  0.371335   1.894376e-65           1      1
# 64        Dengue_cases_t-12  0.603030  2.060625e-195           1      1
# 34                  DTR_t-8 -0.250557   1.397764e-29           1      1
# 24                  DTR_t-6 -0.274027   2.856386e-35           1      1
# 15                  DTR_t-4 -0.268727   6.185318e-34           1      1
# 5                   DTR_t-2 -0.267665   1.135957e-33           1      0
# 55                 DTR_t-12 -0.205816   2.751199e-20           1      1
# 45                 DTR_t-10 -0.241372   1.646872e-27           1      1
# 36              BR_minT_t-8  0.185831   9.150230e-17           1      1
# 26              BR_minT_t-6  0.180721   6.329238e-16           1      1
# 17              BR_minT_t-4  0.162735   3.679842e-13           1      1
# 7               BR_minT_t-2  0.151224   1.513389e-11           1      1
# 57             BR_minT_t-12  0.158237   1.624946e-12           1      1
# 47             BR_minT_t-10  0.186561   6.907656e-17           1      1
#
#     RandomForest  GradientBoost  SVM  Linear Reg  AdaBoost  Sum
# 0              1              1    1           0         1    6
# 40             0              1    1           0         1    5
# 10             0              0    1           0         0    3
# 60             0              0    1           0         1    4
# 19             0              0    0           0         1    3
# 59             1              0    0           0         0    3
# 4              1              1    0           1         1    6
# 54             1              0    0           1         0    3
# 42             0              1    0           0         1    4
# 30             1              0    0           0         0    3
# 21             1              0    0           0         1    4
# 3              1              0    0           1         0    4
# 2              0              0    1           0         0    3
# 32             0              1    1           0         1    5
# 41             1              1    0           0         0    3
# 29             1              1    0           0         0    4
# 20             1              1    0           0         0    4
# 11             1              0    0           0         0    3
# 61             1              0    0           0         1    3
# 1              0              0    1           0         0    3
# 43             0              0    1           0         1    4
# 31             1              1    1           0         1    6
# 22             1              0    1           0         1    5
# 13             1              0    1           0         0    4
# 63             0              1    1           0         1    5
# 52             0              1    1           0         1    5
# 64             1              1    1           0         1    6
# 34             0              0    1           0         0    3
# 24             0              0    1           0         0    3
# 15             0              0    1           0         0    3
# 5              0              0    1           1         0    3
# 55             0              0    1           1         0    4
# 45             0              1    1           0         0    4
# 36             0              0    0           1         0    3
# 26             0              0    0           1         0    3
# 17             0              0    0           1         0    3
# 7              0              0    0           1         0    3
# 57             0              0    0           1         0    3
# 47             0              0    0           1         0    3

# %% [markdown]
# -------
# ### Testing for correlations between the selected variables

# %%
var_list = list(varSel.Variable[varSel['Sum']>=3])

# %%
var_df = scale_df[var_list].copy()
var_df.head()
# Out:
#         week  altitude  city_dens  max_temp_t-2  min_temp_t-2   DTR_t-2  \
# 12  0.019231  0.196227        0.0      0.730511      0.707677  0.622417
# 13  0.038462  0.196227        0.0      0.663978      0.719115  0.531797
# 14  0.057692  0.196227        0.0      0.516801      0.745043  0.330684
# 15  0.076923  0.196227        0.0      0.573925      0.726741  0.417329
# 16  0.096154  0.196227        0.0      0.523522      0.708439  0.376789
#
#     BR_minT_t-2  sea_level_pressure_t-2  avg_humidity_t-2  Gust_t-2   DTR_t-4  \
# 12     0.666667                0.250657          0.569501  0.396570  0.451510
# 13     0.666667                0.352141          0.557528  0.264737  0.528617
# 14     0.666667                0.260094          0.753387  0.394427  0.622417
# 15     0.666667                0.198343          0.798155  0.486602  0.531797
# 16     0.666667                0.300350          0.746490  0.362272  0.330684
#
#     BR_minT_t-4  rain_log_t-4  avg_humidity_t-4  min_humidity_t-4  Gust_t-4  \
# 12     0.666667      0.882050          0.781107          0.478355  0.584137
# 13     0.666667      0.680615          0.651098          0.359307  0.401929
# 14     0.666667      0.661132          0.569501          0.272727  0.396570
# 15     0.666667      0.703740          0.557528          0.294372  0.264737
# 16     0.666667      0.853548          0.753387          0.534632  0.394427
#
#      DTR_t-6  BR_minT_t-6  avg_humidity_t-6  min_humidity_t-6  Gust_t-6  \
# 12  0.382353     0.666667          0.733606          0.491342  0.387996
# 13  0.521463     0.666667          0.628584          0.350649  0.396570
# 14  0.451510     0.666667          0.781107          0.478355  0.584137
# 15  0.528617     0.666667          0.651098          0.359307  0.401929
# 16  0.622417     0.666667          0.569501          0.272727  0.396570
#
#     avg_wind_t-6   DTR_t-8  BR_minT_t-8  sea_level_pressure_t-8  \

#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col6,#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col5,#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col7,#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col0,#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col1,#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col2,#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col3,#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col7{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col0{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col2{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col3{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col4,#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col4{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col5,#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col6,#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row1_col7{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col0{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col1{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col3{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col4{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row2_col6{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col0{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col2{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col4{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col5{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col6{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row3_col7{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col0{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col1{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col3{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col5{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col6{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row4_col7{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col1,#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col4{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col2{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col3{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col6{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row5_col7{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col0{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col1{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col2{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col3{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row6_col5{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_a554f863_22cb_11ec_b73f_d45d64b46771row7_col6{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }</style><table id="T_a554f863_22cb_11ec_b73f_d45d64b46771" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >avg_humidity_t-2</th>        <th class="col_heading level0 col1" >avg_humidity_t-4</th>        <th class="col_heading level0 col2" >min_humidity_t-4</th>        <th class="col_heading level0 col3" >avg_humidity_t-6</th>        <th class="col_heading level0 col4" >min_humidity_t-6</th>        <th class="col_heading level0 col5" >avg_humidity_t-8</th>        <th class="col_heading level0 col6" >min_humidity_t-8</th>        <th class="col_heading level0 col7" >avg_humidity_t-12</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a554f863_22cb_11ec_b73f_d45d64b46771level0_row0" class="row_heading level0 row0" >avg_humidity_t-2</th>
#                         <td id="T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col1" class="data row0 col1" >0.455809</td>
#                         <td id="T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col2" class="data row0 col2" >0.370113</td>
#                         <td id="T_a554f863_22cb_11ec_b73f_d45d64b46771row0_col3" class="data row0 c

# %%
var_df.drop(columns = ['min_humidity_t-4', 'min_humidity_t-6', 'min_humidity_t-8'], inplace = True)

# %%
var_df.drop(columns = ["altitude"], inplace = True)
var_df.shape
# Out:
# (1970, 35)

# %%
var_corrMatrix = var_df.corr(method = 'spearman')
var_corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col0,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row1_col1,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col2,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row3_col3,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row4_col4,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row5_col5,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row6_col6,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row7_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row8_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row9_col9,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row10_col10,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row11_col11,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row13_col13,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row14_col14,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row15_col15,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row16_col16,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row17_col17,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row18_col18,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row19_col19,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row20_col20,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row21_col21,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row22_col22,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row23_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row24_col24,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row25_col25,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row26_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row27_col27,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col28,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row29_col29,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row30_col30,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row31_col31,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row32_col32,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row33_col33,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row34_col34{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col1,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row1_col30,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col33,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row10_col18,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row17_col0,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row17_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row18_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row22_col25,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row30_col4,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row31_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row33_col2{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col2,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row7_col31,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row9_col13,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row26_col31{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col3,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row7_col14,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row8_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row10_col31,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col18,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col19,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row16_col0,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row19_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row21_col2,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row22_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row24_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row25_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row26_col32,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col22,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row31_col22{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col4,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row13_col2,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row20_col28,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col20,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row29_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row34_col18{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col5,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col21,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row8_col28,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row11_col4,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col3,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row13_col32,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row16_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row20_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row21_col16,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row26_col22,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row27_col34,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col25{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col6,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col25,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row7_col20,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col32,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row20_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row25_col2,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row25_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row30_col3,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row30_col33{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col13,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row11_col14,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row14_col27,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row24_col15,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row27_col9,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row32_col19{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col9,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row7_col15,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row10_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row11_col30,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row14_col3,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row19_col5,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row23_col27,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row27_col22,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row28_col6{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col10,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row2_col16,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row19_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row19_col26,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row24_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row24_col33,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row31_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row31_col23{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col11,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row6_col1,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row10_col0,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row12_col31,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row22_col23,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row32_col8,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row32_col13,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row32_col23{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0_d45d64b46771row0_col12,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row1_col31,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row6_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row8_col32,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row13_col7,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row13_col34,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row16_col11,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row16_col15,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row18_col25,#T_240d8f83_22cc_11ec_87d0_d45d64b46771row23_col0{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_240d8f83_22cc_11ec_87d0

# %%
var_df.drop(columns = ["BR_minT_t-2", "max_temp_t-2", "avg_wind_t-6","BR_minT_t-12" ], inplace = True)

# %%
var_df.shape
# Out:
# (1970, 31)

# %%
var_df['Dengue_cases'] =df['Dengue_cases'].values

# %%
var_df.head()
# Out:
#         week  city_dens  min_temp_t-2   DTR_t-2  sea_level_pressure_t-2  \
# 12  0.019231        0.0      0.707677  0.622417                0.250657
# 13  0.038462        0.0      0.719115  0.531797                0.352141
# 14  0.057692        0.0      0.745043  0.330684                0.260094
# 15  0.076923        0.0      0.726741  0.417329                0.198343
# 16  0.096154        0.0      0.708439  0.376789                0.300350
#
#     avg_humidity_t-2  Gust_t-2   DTR_t-4  BR_minT_t-4  rain_log_t-4  \
# 12          0.569501  0.396570  0.451510     0.666667      0.882050
# 13          0.557528  0.264737  0.528617     0.666667      0.680615
# 14          0.753387  0.394427  0.622417     0.666667      0.661132
# 15          0.798155  0.486602  0.531797     0.666667      0.703740
# 16          0.746490  0.362272  0.330684     0.666667      0.853548
#
#     avg_humidity_t-4  Gust_t-4   DTR_t-6  BR_minT_t-6  avg_humidity_t-6  \
# 12          0.781107  0.584137  0.382353     0.666667          0.733606
# 13          0.651098  0.401929  0.521463     0.666667          0.628584
# 14          0.569501  0.396570  0.451510     0.666667          0.781107
# 15          0.557528  0.264737  0.528617     0.666667          0.651098
# 16          0.753387  0.394427  0.622417     0.666667          0.569501
#
#     Gust_t-6   DTR_t-8  BR_minT_t-8  sea_level_pressure_t-8  avg_humidity_t-8  \
# 12  0.387996  0.364865     0.666667                0.302595          0.748442
# 13  0.396570  0.432432     0.666667                0.269950          0.676605
# 14  0.584137  0.382353     0.666667                0.270075          0.733606
# 15  0.401929  0.521463     0.666667                0.239723          0.628584
# 16  0.396570  0.451510     0.666667                0.125561          0.781107
#
#     Gust_t-8  DTR_t-10  BR_minT_t-10  Gust_t-10  min_temp_t-12  DTR_t-12  \
# 12  0.274384  0.495231      0.666667   0.474812       0.591726  0.590660
# 13  0.284030  0.298092      0.666667   0.370847       0.674886  0.687599
# 14  0.387996  0.364865      0.666667   0.274384       0.706914  0.495231
# 15  0.396570  0.432432      0.666667   0.284030       0.699288  0.298092
# 16  0.584137  0.382353      0.666667   0.387996       0.597102  0.364865
#
#     rain_log_t-12  sea_level_pressure_t-12  avg_humidity_t-12  Gust_t-12  \
# 12       0.717383                 0.406557           0.530878   0.485798
# 13       0.495234                 0.315404           0.409797   0.357985
# 14       0.706801                 0.264046           0.586221   0.474812
# 15       0.881483                 0.327509           0.693848   0.370847
# 16       0.876808                 0.357960           0.718071   0.274384
#
#     Dengue_cases_t-12  Dengue_cases
# 12                0.0             0
# 13                0.0             0
# 14                0.0             0
# 15                0.0             0
# 16                0.0             0

# %%
var_df.to_csv("final_cilmate_medical2.csv")

# %% [markdown]
# ### Dataset Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
#split to test (0.2) and temp=train+dev (0.8)

X= var_df.loc[:,var_df.columns != 'Dengue_cases' ]
y = var_df['Dengue_cases']

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X,y,test_size=400, random_state = 13)
X_temp.shape
# Out:
# (1570, 31)

# %%
from scipy import stats

# %%
def ks_test(df1, df2):
    """performs two-sample Kolmogorov-Smirnov
    params: two dataframes with same columns
    returns: dataframe with ks results for every column
    """
    KS = []
    p_value = []

    for col in df1.columns:      
        ks, p = stats.ks_2samp(df1[col], df2[col])
        KS.append(ks)
        p_value.append(p)
    
    ks_df = pd.DataFrame({"variable": df1.columns, "KS": KS, "p_value": p_value})
    return ks_df

# %%
test_temp_ks = ks_test(X_temp, X_test)
test_temp_ks
# Out:
#                    variable        KS   p_value
# 0                      week  0.024363  0.988767
# 1                 city_dens  0.027834  0.958929
# 2              min_temp_t-2  0.034586  0.824984
# 3                   DTR_t-2  0.048869  0.416229
# 4    sea_level_pressure_t-2  0.049554  0.398962
# 5          avg_humidity_t-2  0.066290  0.115237
# 6                  Gust_t-2  0.055844  0.261659
# 7                   DTR_t-4  0.035334  0.805045
# 8               BR_minT_t-4  0.018041  0.999893
# 9              rain_log_t-4  0.031688  0.893949
# 10         avg_humidity_t-4  0.037850  0.733661
# 11                 Gust_t-4  0.037006  0.758210
# 12                  DTR_t-6  0.032500  0.876134
# 13              BR_minT_t-6  0.003917  1.000000
# 14         avg_humidity_t-6  0.043678  0.559589
# 15                 Gust_t-6  0.065239  0.125960
# 16                  DTR_t-8  0.044857  0.525390
# 17              BR_minT_t-8  0.011768  1.000000
# 18   sea_level_pressure_t-8  0.033280  0.857850
# 19         avg_humidity_t-8  0.055127  0.275323
# 20                 Gust_t-8  0.046322  0.484088
# 21                 DTR_t-10  0.027707  0.960494
# 22             BR_minT_t-10  0.019602  0.999478
# 23                Gust_t-10  0.039315  0.690144
# 24            min_temp_t-12  0.039140  0.695389
# 25                 DTR_t-12  0.018583  0.999806
# 26            rain_log_t-12  0.042468  0.595405
# 27  sea_level_pressure_t-12  0.041019  0.638879
# 28        avg_humidity_t-12  0.042532  0.593511
# 29                Gust_t-12  0.027627  0.961450
# 30        Dengue_cases_t-12  0.042245  0.602066

# %%
stats.ks_2samp(y_temp, y_test)
# Out:
# KstestResult(statistic=0.025621019108280255, pvalue=0.9808442352540712)

# %%
fig, axes = plt.subplots(1,2, figsize=(16,5))
sns.distplot(y_temp, ax=axes[0])
axes[0].set_title("y_temp")
sns.distplot(y_test, ax=axes[1])
axes[1].set_title("y_test")
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'y_test')

# %%
#split to train and dev

X_train, X_dev, y_train, y_dev = train_test_split(X_temp, y_temp, test_size=350, random_state = 123)

# %%
X_train.shape
# Out:
# (1220, 31)

# %%
train_dev_ks = ks_test(X_train, X_dev)
train_dev_ks
# Out:
#                    variable        KS   p_value
# 0                      week  0.031639  0.938649
# 1                 city_dens  0.024028  0.996330
# 2              min_temp_t-2  0.045246  0.614121
# 3                   DTR_t-2  0.059508  0.277460
# 4    sea_level_pressure_t-2  0.036534  0.845191
# 5          avg_humidity_t-2  0.068197  0.150983
# 6                  Gust_t-2  0.039906  0.760968
# 7                   DTR_t-4  0.040609  0.742149
# 8               BR_minT_t-4  0.016323  0.999999
# 9              rain_log_t-4  0.049508  0.499172
# 10         avg_humidity_t-4  0.040117  0.755342
# 11                 Gust_t-4  0.035176  0.875202
# 12                  DTR_t-6  0.050468  0.474564
# 13              BR_minT_t-6  0.015152  1.000000
# 14         avg_humidity_t-6  0.054731  0.373333
# 15                 Gust_t-6  0.042131  0.700595
# 16                  DTR_t-8  0.081429  0.050856
# 17              BR_minT_t-8  0.009461  1.000000
# 18   sea_level_pressure_t-8  0.050281  0.479328
# 19         avg_humidity_t-8  0.068314  0.149665
# 20                 Gust_t-8  0.067658  0.157179
# 21                 DTR_t-10  0.068080  0.152314
# 22             BR_minT_t-10  0.011897  1.000000
# 23                Gust_t-10  0.052974  0.413362
# 24            min_temp_t-12  0.031101  0.946203
# 25                 DTR_t-12  0.045012  0.620589
# 26            rain_log_t-12  0.052084  0.434564
# 27  sea_level_pressure_t-12  0.063208  0.216385
# 28        avg_humidity_t-12  0.036206  0.852689
# 29                Gust_t-12  0.027822  0.979876
# 30        Dengue_cases_t-12  0.062412  0.228582

# %%
stats.ks_2samp(y_train, y_dev)
# Out:
# KstestResult(statistic=0.03641686182669789, pvalue=0.8478843295816898)

# %%
fig, axes = plt.subplots(1,2, figsize=(16,5))
sns.distplot(y_train, ax=axes[0])
axes[0].set_title("y_train")
sns.distplot(y_dev, ax=axes[1])
axes[1].set_title("y_dev")
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'y_dev')

# %%
print("X_train",X_train.shape)
print("X_dev",X_dev.shape)
print("X_test",X_test.shape)
# Out:
# X_train (1220, 31)
# X_dev (350, 31)
# X_test (400, 31)

# %% [markdown]
# ### Model selction

# %%
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
model_list = [LinearRegression(), Ridge(), DecisionTreeRegressor(), RandomForestRegressor(), AdaBoostRegressor(), GradientBoostingRegressor(),
             SVR(), KNeighborsRegressor()]
model_names = ["LinearRegession", "Ridge", "Desion Tree", "RandomForest", "AdaBoost", "GradientBoosting", "SVR", "KNN"]
MSE_res = []
R2_res = []
MAE_res = []


for model in model_list:
    mod = model
    mod.fit(X_train, y_train)
    y_pred = mod.predict(X_dev)
    MSE = metrics.mean_squared_error(y_dev,y_pred)
    MAE = metrics.mean_absolute_error(y_dev,y_pred)
    r2 = metrics.r2_score(y_dev,y_pred)
    MSE_res.append(MSE)
    R2_res.append(r2)
    MAE_res.append(MAE)

        
res_df = pd.DataFrame({'Model': model_names, 'MSE': MSE_res, 'MAE': MAE_res, 'R2': R2_res}) 
    
res_df
# Out:
#               Model            MSE         MAE        R2
# 0   LinearRegession   60533.999777   81.762799  0.085821
# 1             Ridge   60335.822595   79.674001  0.088814
# 2       Desion Tree  114844.928571   71.460000 -0.734377
# 3      RandomForest   52896.630201   57.629971  0.201160
# 4          AdaBoost   60347.418758  131.003963  0.088639
# 5  GradientBoosting   36010.681162   48.355525  0.456170
# 6               SVR   67481.620794   42.972029 -0.019101
# 7               KNN   51828.118743   53.674857  0.217297

# %%
res_df.sort_values("MSE")
# Out:
#               Model            MSE         MAE        R2
# 5  GradientBoosting   36010.681162   48.355525  0.456170
# 7               KNN   51828.118743   53.674857  0.217297
# 3      RandomForest   52896.630201   57.629971  0.201160
# 1             Ridge   60335.822595   79.674001  0.088814
# 4          AdaBoost   60347.418758  131.003963  0.088639
# 0   LinearRegession   60533.999777   81.762799  0.085821
# 6               SVR   67481.620794   42.972029 -0.019101
# 2       Desion Tree  114844.928571   71.460000 -0.734377

# %% [markdown]
# ### Hyperparameter Fine-Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
gbmodel = GradientBoostingRegressor(random_state = 13)

loss = ['squared_error', 'absolute_error', 'lad']
learning_rate = [1, 0.5, 0.1, 0.01, 0.001]
n_estimators = [10, 50, 100, 500, 1000, 5000]
max_depth = [3, 10, 30, 70]

params = {'loss': loss, 'learning_rate': learning_rate, 'n_estimators':n_estimators, 'max_depth':max_depth}

# %%
gb_random = RandomizedSearchCV(estimator = gbmodel, param_distributions = params, n_iter = 100, n_jobs = -1, random_state= 123, cv = 10, verbose = 2)
gb_random.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  5.5min finished
# RandomizedSearchCV(cv=10, estimator=GradientBoostingRegressor(random_state=13),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'learning_rate': [1, 0.5, 0.1, 0.01,
#                                                           0.001],
#                                         'loss': ['squared_error',
#                                                  'absolute_error', 'lad'],
#                                         'max_depth': [3, 10, 30, 70],
#                                         'n_estimators': [10, 50, 100, 500, 1000,
#                                                          5000]},
#                    random_state=123, verbose=2)

# %%
best_random = gb_random.best_estimator_
y_random = gb_random.predict(X_dev)
mse_score = metrics.mean_squared_error(y_dev,y_random)
r2_score = metrics.r2_score(y_dev,y_random)

# %%
print("Best parameters:",gb_random.best_params_)
print("Mean Squared Error:", mse_score)
print("R2:", r2_score)
# Out:
# Best parameters: {'n_estimators': 1000, 'max_depth': 30, 'loss': 'lad', 'learning_rate': 0.001}
# Mean Squared Error: 62196.939230758355
# R2: 0.060707934544777076

# %%
#grid search
from sklearn.model_selection import GridSearchCV

# %%
gbmodel_grid = GradientBoostingRegressor( random_state = 80)


learning_rate = [0.001, 0.01, 0.05, 0.1, 0.5, 0.8]
n_estimators = [50, 100, 500, 1000, 2000]
max_depth = [3, 10, 30, 100]

grid_params = { 'learning_rate': learning_rate, 'n_estimators':n_estimators, 'max_depth':max_depth}



gb_grid= GridSearchCV(estimator = gbmodel_grid, param_grid = grid_params, n_jobs = -1, cv = 10, verbose = 2)
gb_grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 120 candidates, totalling 1200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 981 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=-1)]: Done 1200 out of 1200 | elapsed: 25.6min finished
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(random_state=80),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.5, 0.8],
#                          'max_depth': [3, 10, 30, 100],
#                          'n_estimators': [50, 100, 500, 1000, 2000]},
#              verbose=2)

# %%
gb_grid.best_params_
# Out:
# {'learning_rate': 0.001, 'max_depth': 100, 'n_estimators': 100}

# %%
best_grid = gb_grid.best_estimator_
y_grid = gb_grid.predict(X_dev)
mse_score = metrics.mean_squared_error(y_dev,y_grid)
r2_score = metrics.r2_score(y_dev,y_grid)

# %%
print("Best parameters:",gb_grid.best_params_)
print("Mean Squared Error:", mse_score)
print("R2:", r2_score)
# Out:
# Best parameters: {'learning_rate': 0.001, 'max_depth': 100, 'n_estimators': 100}
# Mean Squared Error: 63280.95251755295
# R2: 0.04433727239118568

# %%
gb_base = GradientBoostingRegressor(random_state = 80)
gb_base.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=80)

# %%
y_base = gb_base.predict(X_dev)
mse_score = metrics.mean_squared_error(y_dev,y_base)
r2_score = metrics.r2_score(y_dev,y_base)

# %%
print("Base model")
print("Mean Squared Error:", mse_score)
print("R2:", r2_score)
# Out:
# Base model
# Mean Squared Error: 35829.06772140482
# R2: 0.4589129394532899

# %% [markdown]
# Grid search did not give better results than base model

# %%
import pickle

# %%
file1= "GradientBoosting_base_model.pkl"
with open(file1, 'wb') as file:  
    pickle.dump(gb_base, file)

# %% [markdown]
# ### Runing the model on the test subset

# %%
y_prdiction = gb_base.predict(X_test)

# %%
mse_score = metrics.mean_squared_error(y_test,y_prdiction)
r2_score = metrics.r2_score(y_test,y_prdiction)
print("Model on X_test")
print("Mean Squared Error:", mse_score)
print("R2:", r2_score)
# Out:
# Model on X_test
# Mean Squared Error: 7700.693616274058
# R2: 0.6098167413493605

# %%
plt.figure(figsize=(13, 6))
plt.title("y_test vs. y_predict GB model", fontsize =  'x-large')
sns.scatterplot(x= y_test, y= y_prdiction)
plt.ylabel("y_predict")
# Out:
# Text(0, 0.5, 'y_predict')

# %%
plt.figure(figsize=(13, 6))
sns.scatterplot(x= y_dev, y= y_base)
plt.title("y_dev vs. y_dev_predict GB model", fontsize =  'x-large')
plt.ylabel("y_dev_predict")
# Out:
# Text(0, 0.5, 'y_dev_predict')

# %%
plt.figure(figsize=(13, 6))
plt.title("Real vs. Predicted - Test subset GB model", fontsize =  'xx-large')
plt.hist(y_test, alpha=0.3, color = 'red',  bins =50)
plt.hist(y_prdiction, alpha=0.3, color = 'black',  bins =50)
plt.legend(("y_test", "y_predict"), loc='upper right', fontsize = 'large')

# %%
plt.figure(figsize=(13, 6))
plt.title("Real vs. Predicted - Test subset (>50) GB model", fontsize =  'xx-large')
plt.hist(y_test, alpha=0.3, color = 'red', range = (50, 1800),bins =50)
plt.hist( y_prdiction, alpha=0.3, color = 'black', range = (50, 1800), bins =50)
plt.legend(("y_test", "y_predict"), loc='upper right', fontsize = 'large')

# %%
plt.figure(figsize=(13, 6))
plt.title("Real vs. Predicted - Dev subset GB model", fontsize =  'xx-large')
plt.hist(y_dev, color = 'red', alpha=0.3, bins =50)
plt.hist(y_base, alpha=0.3, color = 'black', bins =50)
plt.legend(("y_dev", "y_dev_predict"), loc='upper right', fontsize = 'large')

# %%
plt.figure(figsize=(13, 6))
plt.title("Real vs. Predicted - Dev subset (>50) GB model", fontsize =  'xx-large')
plt.hist(y_dev, color = 'red', alpha=0.3, bins =35, range = (50, 3000))
plt.hist(y_base, alpha=0.3, color = 'black', bins =35, range = (50, 3000))
plt.legend(("y_dev", "y_dev_predict"), loc='upper right', fontsize = 'large')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.scatterplot(x= y_test, y= y_prdiction, ax = ax)
plt.title("y_test vs. y_predict GB model", fontsize =  'x-large')
plt.ylabel('y_predict')
ax.set_xlim(-5,50)
ax.set_ylim(-20,50)
# Out:
# (-20.0, 50.0)
